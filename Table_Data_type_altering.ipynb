# %%
import pandas as pd
import numpy as np 
import re
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
from pathlib import Path
from shapely.ops import transform
from pyproj import Transformer

# %%
df = pd.read_csv('../notebooks/County_DCS_Region.csv')

# %%
df.columns.tolist()
# Out:
# ['County_FIPS',
#  'County',
#  'DCS_Region',
#  'n_youth',
#  'Mental Health - Behavioral & Impulse Control - High Risk',
#  'Mental Health - Cultural, Spiritual, and Engagement Factors - High Risk',
#  'Mental Health - Mood & Emotional Regulation - High Risk',
#  'Mental Health - Physical & Medical - High Risk',
#  'Mental Health - Psychotic & Thought Disturbances - High Risk',
#  'Mental Health - Risk & Safety - High Risk',
#  'Mental Health - Sexual & Developmental Concerns - High Risk',
#  'Mental Health - Trauma & Stress-Related - High Risk',
#  'Supportive Adult Relationships - Family Relationships - High Risk',
#  'Supportive Adult Relationships - Social Relationships - High Risk',
#  'Supportive Adult Relationships - Barriers to Support - High Risk',
#  'Housing Instability - Skills & Readiness - High Risk',
#  'Housing Instability - Current Living Situation - High Risk',
#  'Housing Instability - Barriers & Risks - High Risk',
#  'Decision-Making (Judgement)',
#  'Impulsivity/Hyperactivity',
#  'School Behavior',
#  'Substance Use',
#  'Spiritual/Religious',
#  'Traditions And Rituals',
#  'Youth Involvement With Care',
#  'Anger Control',
#  'Anxiety',
#  'Depression',
#  'Emotional And/Or Physical Dysregulation',
#  'Numbing',
#  'Medical/Physical',
#  'Psychosis (Thought Disorder)',
#  'Danger To Others',
#  'Intentional Misbehavior',
#  'Non-Suicidal Self-Injurious Behavior',
#  'Other Self-Harm (Recklessness)',
#  'Suicide Risk',
#  'Sexual Aggression',
#  'Sexual Development',
#  'Adjustment To Trauma',
#  'Cultural Stress',
#  'Emotional Abuse',
#  'Environmental Influences',
#  'Medical Trauma',
#  'Sexual Abuse',
#  'Attachment Difficulties',
#  'Community Life',
#  'Family Functioning',
#  'Family Strengths',
#  'Interpersonal/Social Connectedness',
#  'Natural Supports',
#  'Neglect',
#  'Oppositional(Non-compliance with Authority)',
#  'Relationship Permanence',
#  'Social Functioning',
#  'Independent Living Skills',
#  'Living Situation',
#  'Physical Abuse',
#  'Runaway*',
#  'Youth Residential Stability']

# %%
df['County'] = (
    df['County'].astype(str).str.strip()
      .str.replace(r'\s*County$', '', regex=True)  # remove existing "County" suffix if present
      .str.strip() + ' County'                     # append once
)

# %%
df.head()
# Out:
#    County_FIPS           County        DCS_Region  n_youth  \
# 0        47065  Hamilton County  Tennessee Valley      515
# 1        47115    Marion County  Tennessee Valley      515
# 2        47185     White County  Upper Cumberland      428
# 3        47129    Morgan County              East      311
# 4        47013  Campbell County              East      311
#
#    Mental Health - Behavioral & Impulse Control - High Risk  \
# 0                                            52.4272
# 1                                            52.4272
# 2                                            54.2056
# 3                                            54.3408
# 4                                            54.3408
#
#    Mental Health - Cultural, Spiritual, and Engagement Factors - High Risk  \
# 0                                            68.9320
# 1                                            68.9320
# 2                                            68.4579
# 3                                            76.2058
# 4                                            76.2058
#
#    Mental Health - Mood & Emotional Regulation - High Risk  \
# 0                                            53.7864
# 1                                            53.7864
# 2                                            48.5981
# 3                                            60.1286
# 4                                            60.1286
#
#    Mental Health - Physical & Medical - High Risk  \
# 0                                          6.2136
# 1                                          6.2136
# 2                                          5.8411
# 3                                         12.8617
# 4                                         12.8617
#
#    Mental Health - Psychotic & Thought Disturbances - High Risk  \
# 0                                             1.5534
# 1                                             1.5534
# 2                                             1.1682
# 3                                             2.2508
# 4                                             2.2508
#
#    Mental Health - Risk & Safety - High Risk  ...  Natural Supports  Neglect  \
# 0                                    23.8835  ...           74.7573  30.8738
# 1                                    23.8835  ...           74.7573  30.8738
# 2                                    13.7850  ...           72.8972  61.9159
# 3                                    25.0804  ...           78.1350  58.8424
# 4                                    25.0804  ...           78.1350  58.8424
#
#    Oppositional(Non-compliance with Authority)  Relationship Permanence  \
# 0                                      27.1845                  37.0874
# 1                                      27.1845                  37.0874
# 2                                      12.6168                  50.2336
# 3                                      24.7588                  45.9807
# 4                                      24.7588                  45.9807
#
#    Social Functioning  Independent Living Skills  Living Situation  \
# 0             34.9515                    13.0097           21.7476
# 1             34.9515                    13.0097           21.7476
# 2             20.0935                     9.1121           18.4579
# 3             33.1190                    13.8264           17.3633
# 4             33.1190                    13.8264           17.3633
#
#    Physical Abuse  Runaway*  Youth Residential Stability
# 0         16.8932   10.4854                       6.6019
# 1         16.8932   10.4854                       6.6019
# 2         28.0374    7.0093                       9.3458
# 3         21.5434   13.1833                       7.0740
# 4         21.5434   13.1833                       7.0740
#
# [5 rows x 60 columns]

# %%
# drop leading 47 via modulo, then convert to 3-char string
df['County_FIPS'] = (df['County_FIPS'] % 1000).astype(int).astype(str).str.zfill(3)

# %%
df.head()
# Out:
#   County_FIPS           County        DCS_Region  n_youth  \
# 0         065  Hamilton County  Tennessee Valley      515
# 1         115    Marion County  Tennessee Valley      515
# 2         185     White County  Upper Cumberland      428
# 3         129    Morgan County              East      311
# 4         013  Campbell County              East      311
#
#    Mental Health - Behavioral & Impulse Control - High Risk  \
# 0                                            52.4272
# 1                                            52.4272
# 2                                            54.2056
# 3                                            54.3408
# 4                                            54.3408
#
#    Mental Health - Cultural, Spiritual, and Engagement Factors - High Risk  \
# 0                                            68.9320
# 1                                            68.9320
# 2                                            68.4579
# 3                                            76.2058
# 4                                            76.2058
#
#    Mental Health - Mood & Emotional Regulation - High Risk  \
# 0                                            53.7864
# 1                                            53.7864
# 2                                            48.5981
# 3                                            60.1286
# 4                                            60.1286
#
#    Mental Health - Physical & Medical - High Risk  \
# 0                                          6.2136
# 1                                          6.2136
# 2                                          5.8411
# 3                                         12.8617
# 4                                         12.8617
#
#    Mental Health - Psychotic & Thought Disturbances - High Risk  \
# 0                                             1.5534
# 1                                             1.5534
# 2                                             1.1682
# 3                                             2.2508
# 4                                             2.2508
#
#    Mental Health - Risk & Safety - High Risk  ...  Natural Supports  Neglect  \
# 0                                    23.8835  ...           74.7573  30.8738
# 1                                    23.8835  ...           74.7573  30.8738
# 2                                    13.7850  ...           72.8972  61.9159
# 3                                    25.0804  ...           78.1350  58.8424
# 4                                    25.0804  ...           78.1350  58.8424
#
#    Oppositional(Non-compliance with Authority)  Relationship Permanence  \
# 0                                      27.1845                  37.0874
# 1                                      27.1845                  37.0874
# 2                                      12.6168                  50.2336
# 3                                      24.7588                  45.9807
# 4                                      24.7588                  45.9807
#
#    Social Functioning  Independent Living Skills  Living Situation  \
# 0             34.9515                    13.0097           21.7476
# 1             34.9515                    13.0097           21.7476
# 2             20.0935                     9.1121           18.4579
# 3             33.1190                    13.8264           17.3633
# 4             33.1190                    13.8264           17.3633
#
#    Physical Abuse  Runaway*  Youth Residential Stability
# 0         16.8932   10.4854                       6.6019
# 1         16.8932   10.4854                       6.6019
# 2         28.0374    7.0093                       9.3458
# 3         21.5434   13.1833                       7.0740
# 4         21.5434   13.1833                       7.0740
#
# [5 rows x 60 columns]

# %%
df.dtypes
# Out:
# County_FIPS                                                                 object
# County                                                                      object
# DCS_Region                                                                  object
# n_youth                                                                      int64
# Mental Health - Behavioral & Impulse Control - High Risk                   float64
# Mental Health - Cultural, Spiritual, and Engagement Factors - High Risk    float64
# Mental Health - Mood & Emotional Regulation - High Risk                    float64
# Mental Health - Physical & Medical - High Risk                             float64
# Mental Health - Psychotic & Thought Disturbances - High Risk               float64
# Mental Health - Risk & Safety - High Risk                                  float64
# Mental Health - Sexual & Developmental Concerns - High Risk                float64
# Mental Health - Trauma & Stress-Related - High Risk                        float64
# Supportive Adult Relationships - Family Relationships - High Risk          float64
# Supportive Adult Relationships - Social Relationships - High Risk          float64
# Supportive Adult Relationships - Barriers to Support - High Risk           float64
# Housing Instability - Skills & Readiness - High Risk                       float64
# Housing Instability - Current Living Situation - High Risk                 float64
# Housing Instability - Barriers & Risks - High Risk                         float64
# Decision-Making (Judgement)                                                float64
# Impulsivity/Hyperactivity                                                  float64
# School Behavior                                                            float64
# Substance Use                                                              float64
# Spiritual/Religious                                                        float64
# Traditions And Rituals                                                     float64
# Youth Involvement With Care                                                float64
# Anger Control                                                              float64
# Anxiety                                                                    float64
# Depression                                                                 float64
# Emotional And/Or Physical Dysregulation                                    float64
# Numbing                                                                    float64
# Medical/Physical                                                           float64
# Psychosis (Thought Disorder)                                               float64
# Danger To Others                                                           float64
# Intentional Misbehavior                                                    float64
# Non-Suicidal Self-Injurious Behavior                                       float64
# Other Self-Harm (Recklessness)                                             float64
# Suicide Risk                                                               float64
# Sexual Aggression                                                          float64
# Sexual Development                                                         float64
# Adjustment To Trauma                                                       float64
# Cultural Stress                                                            float64
# Emotional Abuse                                                            float64
# Environmental Influences                                                   float64
# Medical Trauma                                                             float64
# Sexual Abuse                                                               float64
# Attachment Difficulties                                                    float64
# Community Life                                                             float64
# Family Functioning                                                         float64
# Family Strengths                                                           float64
# Interpersonal/Social Connectedness                                         float64
# Natural Supports                                                           float64
# Neglect                                                                    float64
# Oppositional(Non-compliance with Authority)                                float64
# Relationship Permanence                                                    float64
# Social Functioning                                                         float64
# Independent Living Skills                                                  float64
# Living Situation                                                           float64
# Physical Abuse                                                             float64
# Runaway*                                                                   float64
# Youth Residential Stability                                                float64
# dtype: object

# %%
# drop leading 47 via modulo, then convert to 3-char string
df['County_FIPS'] = (df['County_FIPS']).astype(str)

# %%
df.to_csv('County_DCS_Region_Matched.csv')
